# %%
# %run randamwalk.py

# %%
# %whos
# Out:
# Variable            Type        Data/Info
# -----------------------------------------
# add_noise           function    <function add_noise at 0x10b2751e0>
# np                  module      <module 'numpy' from '/Us<...>kages/numpy/__init__.py'>
# observed_position   ndarray     100: 100 elems, type `float64`, 800 bytes
# plt                 module      <module 'matplotlib.pyplo<...>es/matplotlib/pyplot.py'>
# random_walker       function    <function random_walker at 0x1078fe6a8>
# sns                 module      <module 'seaborn' from '/<...>ges/seaborn/__init__.py'>
# true_position       ndarray     100: 100 elems, type `float64`, 800 bytes

# %%
plt.show()
